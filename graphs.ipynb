# %%
import pandas as pd
import matplotlib.pyplot as plt
  
# create 2D array of table given above
data = [['K=1', 0.7812500000000001, 0.7812500000000001, 0.8620689655172413, 0.7142857142857143, 30.6875],
        ['K=3', 0.8064516129032258,0.8032786885245902,0.8620689655172413, 0.7575757575757576,0.75],
        ['K=5', 0.8196721311475409,0.819672131147541,0.8620689655172413,0.78125,0.78125],
        ['K=7', 0.8307692307692308,0.819672131147541,0.9310344827586207,0.75, 0.71875],
        ['K=9', 0.8437500000000001,0.8360655737704918,0.9310344827586207,0.7714285714285715,0.75],
        ['K=11', 0.8307692307692308, 0.819672131147541,0.9310344827586207,0.75,0.71875],
        ['K=13', 0.8125,0.8032786885245902,0.896551724137931,0.7428571428571429,0.71875],
        ['K=15', 0.8125,0.8032786885245902,0.896551724137931,0.7428571428571429,0.71875]]
  
# dataframe created with
# the above data array
df = pd.DataFrame(data, columns = ['K','F1-score', 'Accuracy', 
                                    'Recall', 'Precision',
                                    'Specificity'] )
  
# create histogram for numeric data
df.hist()
  
# show plot
plt.show()
